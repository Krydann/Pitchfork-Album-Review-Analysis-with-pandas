# %% [markdown]
# # Testing pandas and matplotlib with Pitchfork Album Reviews
#
# In this notebook I will import Pitchfork data from a .csv in order to manipulate the data set and plot some stuff.

# %%
# First we import the required libraries to manipulate and visualize data.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
# %matplotlib inline

# We read the .csv file and make it a Data Frame. We glimpse at the head to ensure that it was read correctly.
df = pd.read_csv('p4kreviews.csv', index_col = 0)
df.head()
# Out:
#                    album                            artist  best  \
# 1       A.M./Being There                             Wilco     1
# 2               No Shame                            Hopsin     0
# 3       Material Control                          Glassjaw     0
# 4  Weighing of the Heart                     Nabihah Iqbal     0
# 5            The Visitor  Neil Young / Promise of the Real     0
#
#               date    genre  \
# 1  December 6 2017     Rock
# 2  December 6 2017      Rap
# 3  December 6 2017     Rock
# 4  December 6 2017  Pop/R&B
# 5  December 5 2017     Rock
#
#                                               review  score
# 1  Best new reissue 1 / 2 Albums Newly reissued a...    7.0
# 2  On his corrosive fifth album, the rapper takes...    3.5
# 3  On their first album in 15 years, the Long Isl...    6.6
# 4  On her debut LP, British producer Nabihah Iqba...    7.7
# 5  While still pointedly political, Neil Young�s ...    6.7

# %%
# What is the shape of the data frame?
print(df.shape)
# Out:
# (19555, 7)

# %%
# Info summary of the dataframe df.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19555 entries, 1 to 19555
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   album   19550 non-null  object
#  1   artist  19555 non-null  object
#  2   best    19555 non-null  int64
#  3   date    19555 non-null  object
#  4   genre   19555 non-null  object
#  5   review  19554 non-null  object
#  6   score   19555 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.2+ MB

# %%
# We get a count of the missing values per column.
df.isna().sum()
# Out:
# album     5
# artist    0
# best      0
# date      0
# genre     0
# review    1
# score     0
# dtype: int64

# %%
# We drop de columns where there is missing data, since not knowing the album name renders the observation useless.
df = df.dropna()

# %%
# What is the summarized description of the numerical data in df?
df.describe()
# Out:
#                best         score
# count  19549.000000  19549.000000
# mean       0.053200      7.027797
# std        0.224437      1.276728
# min        0.000000      0.000000
# 25%        0.000000      6.500000
# 50%        0.000000      7.300000
# 75%        0.000000      7.800000
# max        1.000000     10.000000

# %%
# Now we plot a histogram of the scores.
df.score.hist(bins = 20, color = 'orange')
plt.title('Distribution of Scores')
plt.xlabel('Score')
plt.ylabel('Count')
plt.show()

# %%
# Let's visualize the ratio of Best New Albums vs non-Best New Albums.
df.best.hist(bins = 2, color = 'purple')
plt.title('Best New Albums')
plt.xlabel('Best')
plt.ylabel('Count')
plt.xticks(np.arange(2), ['Non Best', 'Best'])
plt.show()

# %%
# How many reviews are there by genre? 
df_genre = df
df_genre['count'] = 1
df_genre.groupby(['genre']).count().sort_values('count', ascending = False)['count']
# Out:
# genre
# Rock            6955
# Electronic      4020
# None            2323
# Experimental    1697
# Rap             1481
# Pop/R&B         1157
# Metal            781
# Folk/Country     700
# Jazz             257
# Global           178
# Name: count, dtype: int64

# %%
# Reviews by genre visualization

counts = df['genre'].value_counts()
plt.bar(range(len(counts)), counts, color = 'green')
plt.xticks(range(len(counts)), counts.index, rotation = 90)
plt.show()

# %%
# What is the average album score by genre?

df_score_by_genre = df.groupby(['genre'])['score'].mean()
df_score_by_genre
# Out:
# genre
# Electronic      6.941318
# Experimental    7.359281
# Folk/Country    7.219857
# Global          7.434831
# Jazz            7.568482
# Metal           6.980410
# None            7.020749
# Pop/R&B         6.948315
# Rap             6.950304
# Rock            6.984572
# Name: score, dtype: float64

# %%
# Average score by genre visualization (WIP)
genres = [genre for genre, df in df.groupby('genre')]

plt.bar(genres, df_score_by_genre, color = 'green')
plt.title('Average score by genre')
plt.xlabel('Genre')
plt.ylabel('Avg, Score')
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# The three genres with the highest average scores are Jazz, Global and Experimental in that order.

# %%
# Relation between Best New Music and Score?
plt.scatter(df.score, df.best, color = 'blue')
plt.title('Scores by Best')
plt.xlabel('Score')
plt.ylabel('Is it Best?')
plt.yticks(np.arange(2), ['Non Best', 'Best'])
plt.show()

# %% [markdown]
# Interestingly, there are albums with a score of 10 that are *not* Best New Music, and there are Best New Music albums with a score of about 5.
#
# The first case must have seen a bunch of great music released at the same time, and the second case must have been a pretty shitty time for music.

# %%
# Filtering the data frame to only get reviews of Experimental or None genres.
filterExperimentalNone = np.logical_or(df['genre'] == 'Experimental', df['genre'] == 'None')

ExperimentalNone_df = df[filterExperimentalNone].reset_index()
ExperimentalNone_df
# Out:
#       index                                              album  \
# 0        21  Call Me By Your Name (Original Motion Picture ...
# 1        24                                     Rainbow Mirror
# 2        46                Bill Brewster Presents Tribal Rites
# 3        47                                               FILM
# 4        49                                        Bajas Fresh
# ...     ...                                                ...
# 4015  19527                               Ohia: Axxess and Ace
# 4016  19530                                  Singles 1989-1991
# 4017  19543                                        The Sebadoh
# 4018  19553                        Singles Breaking Up, Vol. 1
# 4019  19555                          Left for Dead in Malaysia
#
#                    artist  best              date         genre  \
# 0         Various Artists     0   December 1 2017          None
# 1                Prurient     0  November 30 2017  Experimental
# 2           Bill Brewster     0  November 21 2017          None
# 3             Qasim Naqvi     0  November 21 2017  Experimental
# 4           Bitchin Bajas     0  November 20 2017  Experimental
# ...                   ...   ...               ...           ...
# 4015                Songs     0     March 15 1999          None
# 4016  The Wedding Present     0      March 9 1999  Experimental
# 4017              Sebadoh     0  February 23 1999  Experimental
# 4018        Don Caballero     0   January 12 1999  Experimental
# 4019       Neil Hamburger     0    January 5 1999          None
#
#                                                  review  score  count
# 0     The soundtrack to Italian director Luca Guadag...    7.6      1
# 1     Commemorating 20 years of his Prurient alias, ...    6.2      1
# 2     A sort of biography in compilation form, Triba...    7.8      1
# 3     Originally composed for a pair of soundtracks,...    7.7      1
# 4     Over seven tracks that span 80 minutes, the ex...    8.0      1
# ...                                                 ...    ...    ...
# 4015  More melancholy acoustic ballads-- who needs '...    8.0      1
# 4016  Less really is more. Take the Wedding Present,...    5.5      1
# 4017  There's nothing more American than marijuana a...    7.4      1
# 4018  Well, kids, I just went back and re-read my re...    7.2      1
# 4019  Neil Hamburger's third comedy release is a des...    6.5      1
#
# [4020 rows x 9 columns]

# %%
#Out of curiosity, I sorted by descending score to see what were the best rated Experimental and no genre albums.
ExperimentalNone_df.sort_values('score', ascending = False)
# Out:
#       index                                              album  \
# 1286   6049                           The Disintegration Loops
# 1910   9261  Ladies and Gentlemen We are Floating in Space ...
# 3346  16406                 No Thanks!: The 70s Punk Rebellion
# 1464   6678          Isn't Anything / Loveless / EPs 1988-1991
# 213    1542                                Another Green World
# ...     ...                                                ...
# 3662  17805                          Children of the Black Sun
# 3905  18791                                   Weird Revolution
# 4013  19503                                    Uterus and Fire
# 2140  10572                                Johnny Cash Remixed
# 2456  12223                                       This Is Next
#
#                    artist  best               date         genre  \
# 1286     William Basinski     1   November 19 2012  Experimental
# 1910        Spiritualized     1       March 2 2010  Experimental
# 3346      Various Artists     0   February 10 2004          None
# 1464  My Bloody Valentine     1        May 11 2012  Experimental
# 213             Brian Eno     0  September 18 2016  Experimental
# ...                   ...   ...                ...           ...
# 3662                  Non     0  September 19 2002  Experimental
# 3905     Butthole Surfers     0     August 31 2001          None
# 4013     Old Time Relijun     0      April 20 1999  Experimental
# 2140      Various Artists     0    January 20 2009          None
# 2456      Various Artists     0     August 22 2007          None
#
#                                                  review  score  count
# 1286  Best new reissue The four volumes of William B...   10.0      1
# 1910  Best new reissue This new deluxe, limited prod...   10.0      1
# 3346  "At its best new wave/punk represents a fundam...   10.0      1
# 1464  Best new reissue Best new reissue Best new rei...   10.0      1
# 213   Brian Eno has done everything�from producing h...   10.0      1
# ...                                                 ...    ...    ...
# 3662  Boyd Rice, that provocative Gnostic, desperate...    0.5      1
# 3905  Hotshot rock album mixers hold an interesting ...    0.4      1
# 4013  I'd say Old Time Relijun's Uterus and Fire is ...    0.3      1
# 2140  Totally inessential. I've been scouring the bo...    0.2      1
# 2456  Basically an ADA sampler with a promotional st...    0.0      1
#
# [4020 rows x 9 columns]

# %%
# Let's separate the date by month, day and year.

df['Month'] = df['date'].apply(lambda x: x.split(' ')[0])
df['Day'] = df['date'].apply(lambda x: x.split(' ')[1])
df['Year'] = df['date'].apply(lambda x: x.split(' ')[2])
df
# Out:
#                              album                            artist  best  \
# 1                 A.M./Being There                             Wilco     1
# 2                         No Shame                            Hopsin     0
# 3                 Material Control                          Glassjaw     0
# 4            Weighing of the Heart                     Nabihah Iqbal     0
# 5                      The Visitor  Neil Young / Promise of the Real     0
# ...                            ...                               ...   ...
# 19551                         1999                           Cassius     0
# 19552               Let Us Replay!                           Coldcut     0
# 19553  Singles Breaking Up, Vol. 1                     Don Caballero     0
# 19554                  Out of Tune                          Mojave 3     0
# 19555    Left for Dead in Malaysia                    Neil Hamburger     0
#
#                   date         genre  \
# 1      December 6 2017          Rock
# 2      December 6 2017           Rap
# 3      December 6 2017          Rock
# 4      December 6 2017       Pop/R&B
# 5      December 5 2017          Rock
# ...                ...           ...
# 19551  January 26 1999    Electronic
# 19552  January 26 1999    Electronic
# 19553  January 12 1999  Experimental
# 19554  January 12 1999          Rock
# 19555   January 5 1999          None
#
#                                                   review  score  count  \
# 1      Best new reissue 1 / 2 Albums Newly reissued a...    7.0      1
# 2      On his corrosive fifth album, the rapper takes...    3.5      1
# 3      On their first album in 15 years, the Long Isl...    6.6      1
# 4      On her debut LP, British producer Nabihah Iqba...    7.7      1
# 5      While still pointedly political, Neil Young�s ...    6.7      1
# ...                                                  ...    ...    ...
# 19551  Well, it's been two weeks now, and I guess it'...    4.8      1
# 19552  The marketing guys of yer average modern megac...    8.9      1
# 19553  Well, kids, I just went back and re-read my re...    7.2      1
# 19554  Out of Tune is a Steve Martin album. Yes, I'll...    6.3      1
# 19555  Neil Hamburger's third comedy release is a des...    6.5      1
#
#           Month Day  Year
# 1      December   6  2017
# 2      December   6  2017
# 3      December   6  2017
# 4      December   6  2017
# 5      December   5  2017
# ...         ...  ..   ...
# 19551   January  26  1999
# 19552   January  26  1999
# 19553   January  12  1999
# 19554   January  12  1999
# 19555   January   5  1999
#
# [19549 rows x 11 columns]

# %%
# What was the number of reviews released each year?

count_by_year = df.groupby(['Year'], sort = True)[['count']].count()
count_by_year
# Out:
#       count
# Year
# 1999    222
# 2000    348
# 2001    467
# 2002    927
# 2003   1060
# 2004   1121
# 2005   1185
# 2006   1184
# 2007   1216
# 2008   1199
# 2009   1159
# 2010   1161
# 2011   1163
# 2012   1182
# 2013   1200
# 2014   1160
# 2015   1135
# 2016   1261
# 2017   1199

# %%
# Let's visualize the reviews by year.

years = [year for year, df in df.groupby('Year')]

plt.bar(years, count_by_year['count'], color = 'pink')
plt.title('Number of Reviews by Year')
plt.xlabel('Year')
plt.ylabel('Number of Reviews')
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# Pitchfork had a massive growth in review output between the years 2001 and 2002, and it has had small but steady growth in the number of reviews published since.

# %% [markdown]
# ## Question 1: How has the mean score changed as time has gone by?
#
# This can tell us a lot about how the rating habits of the reviewers have changed with time.

# %%
#How have review scores changed by year?
print(df.groupby('Year')[['score']].mean())
df.plot(x = 'Year', y = 'score', kind = 'line')
plt.show()
# Out:
#          score
# Year
# 1999  6.859459
# 2000  6.791954
# 2001  7.154176
# 2002  6.821467
# 2003  6.940660
# 2004  7.195629
# 2005  7.044726
# 2006  6.983868
# 2007  6.884622
# 2008  6.881234
# 2009  6.817343
# 2010  6.981912
# 2011  7.036371
# 2012  7.012014
# 2013  7.050167
# 2014  7.083879
# 2015  7.106520
# 2016  7.248295
# 2017  7.348290

# %% [markdown]
# It seems like Pitchfork's average score by year has been steadily increasing since 2009. Is Pitchfork going soft? Is music getting better overall?

# %% [markdown]
# ## Question 2: In 2009, which albums had a rating of over 9.0? What was the dominant genre?
#
# 2009 is my favorite year in modern music because of albums like Bitte Orca, Merriweather Post Pavilion, Logos and Veckatimest. Let's see if any made the list.

# %%
# First we filter the reviews by the year 2009.
df2009 = df[df['Year'] == '2009'].reset_index()
df2009
# Out:
#       index                                              album  \
# 0      9467  Fire in My Bones: Raw + Rare + Otherworldly Af...
# 1      9468                                         Xenophanes
# 2      9469                                           Echo Kid
# 3      9470                                              Klang
# 4      9471  Neil Young / Everybody Knows This Is Nowhere /...
# ...     ...                                                ...
# 1154  10621                                Theater of the Mind
# 1155  10622                                               Luna
# 1156  10623                                     Friendly Fires
# 1157  10624                    Zang Tumb Tuum: The ZTT Box Set
# 1158  10625                         Merriweather Post Pavilion
#
#                     artist  best              date         genre  \
# 0          Various Artists     0  December 11 2009          None
# 1     Omar Rodriguez-L�pez     0  December 11 2009          Rock
# 2             Turbo Fruits     0  December 11 2009    Electronic
# 3                The Rakes     0  December 11 2009    Electronic
# 4               Neil Young     1  December 11 2009          Rock
# ...                    ...   ...               ...           ...
# 1154              Ludacris     0    January 5 2009           Rap
# 1155            The Aliens     0    January 5 2009          Rock
# 1156        Friendly Fires     0    January 5 2009    Electronic
# 1157       Various Artists     0    January 5 2009          None
# 1158     Animal Collective     1    January 5 2009  Experimental
#
#                                                  review  score  count  \
# 0     This gospel�set covers a wide range of approac...    8.4      1
# 1     The latest in a large run of 2009 solo records...    5.7      1
# 2     Once a Be Your Own Pet side project, Turbo Fru...    6.4      1
# 3     The UK indie band returns to the spirit and en...    6.1      1
# 4     Best new reissue Best new reissue Best new rei...    7.8      1
# ...                                                 ...    ...    ...
# 1154  Following his 2007 mixtape with DJ Drama, The ...    5.3      1
# 1155  Three ex-members of the much-missed Beta Band ...    5.6      1
# 1156  This English indie-dance trio's debut shows an...    7.9      1
# 1157  This 25-year anniversary celebration of Trevor...    5.1      1
# 1158  Best new music With their constantly evolving ...    9.6      1
#
#          Month Day  Year
# 0     December  11  2009
# 1     December  11  2009
# 2     December  11  2009
# 3     December  11  2009
# 4     December  11  2009
# ...        ...  ..   ...
# 1154   January   5  2009
# 1155   January   5  2009
# 1156   January   5  2009
# 1157   January   5  2009
# 1158   January   5  2009
#
# [1159 rows x 12 columns]

# %%
top_2009 = df2009[(df2009['artist'] != 'The Beatles') & (df2009['score'] >= 9.0)].sort_values(by='score', ascending = False).reset_index()
#Since the The Beatles remasters were released in 2009, we'll filter out The Beatles to get the actual 2009 albums.
#P.D. The Beatles are legends.
top_2009
# Out:
#     level_0  index                                              album  \
# 0       317   9784                                    The Stone Roses
# 1      1022  10489                                    Paul's Boutique
# 2       881  10348                          Histoire de Melody Nelson
# 3       538  10005                         Reckoning [Deluxe Edition]
# 4       378   9845                  Kid A: Special Collectors Edition
# 5      1158  10625                         Merriweather Post Pavilion
# 6       373   9840               Amnesiac: Special Collectors Edition
# 7        44   9511                                      The Catalogue
# 8       443   9910                Midlife: A Beginner's Guide to Blur
# 9       291   9758                             Keep an Eye on the Sky
# 10       59   9526                    For Your Own Special Sweetheart
# 11      139   9606            The Unforgettable Fire [Deluxe Edition]
# 12      119   9586  Warp20 (Box Set) / Warp20 (Chosen) / Warp20 (R...
# 13      552  10019                                  Hot Buttered Soul
# 14      623  10090                                         Bitte Orca
# 15      795  10262      Black Monk Time / The Early Years (1964-1965)
# 16      311   9778                     Crazy Rhythms / The Good Earth
# 17      269   9736                                              Album
# 18      702  10169                                    Funcrusher Plus
# 19      214   9681                                          Embryonic
# 20      673  10140                                        Veckatimest
# 21       22   9489  New York-Addis-London: The Story of Ethio Jazz...
# 22      169   9636                                        Tarot Sport
# 23       19   9486                     Elvis 75: Good Rockin' Tonight
#
#                artist  best               date         genre  \
# 0     The Stone Roses     1  September 11 2009          Rock
# 1        Beastie Boys     1   February 13 2009           Rap
# 2    Serge Gainsbourg     1      March 26 2009       Pop/R&B
# 3              R.E.M.     1        July 2 2009          Rock
# 4           Radiohead     1     August 25 2009          Rock
# 5   Animal Collective     1     January 5 2009  Experimental
# 6           Radiohead     1     August 26 2009          Rock
# 7           Kraftwerk     1    December 1 2009    Electronic
# 8                Blur     1       July 30 2009          Rock
# 9            Big Star     1  September 18 2009          Rock
# 10             Jawbox     1   November 24 2009          Rock
# 11                 U2     1    November 2 2009          Rock
# 12    Various Artists     1    November 6 2009          None
# 13        Isaac Hayes     1       June 29 2009       Pop/R&B
# 14   Dirty Projectors     1        June 9 2009          Rock
# 15          The Monks     1      April 20 2009          Rock
# 16        The Feelies     1  September 14 2009          Rock
# 17              Girls     1  September 25 2009          Rock
# 18       Company Flow     1        May 15 2009           Rap
# 19   The Flaming Lips     1    October 12 2009          Rock
# 20       Grizzly Bear     1        May 26 2009          Rock
# 21     Mulatu Astatke     1    December 7 2009          Jazz
# 22       Fuck Buttons     1    October 23 2009    Electronic
# 23      Elvis Presley     1    December 8 2009          Rock
#
#                                                review  score  count  \
# 0   Best new reissue A badly needed remaster of th...   10.0      1
# 1   Best new reissue The Beastie Boys' landmark se...   10.0      1
# 2   Best new reissue Almost unbelievably, the Fren...   10.0      1
# 3   Best new reissue The expanded reissues of albu...   10.0      1
# 4   Best new reissue Capitol follows its excavatio...   10.0      1
# 5   Best new music With their constantly evolving ...    9.6      1
# 6   Best new reissue Met with confusion back in 20...    9.5      1
# 7   Best new reissue Long-awaited box from one of ...    9.5      1
# 8   Best new reissue A new comp from a band whose ...    9.4      1
# 9   Best new reissue Combining studio tracks, live...    9.3      1
# 10  Best new reissue The D.C. band's 1994 major la...    9.3      1
# 11  Best new reissue U2's first collaboration with...    9.3      1
# 12  Best new reissue Best new reissue Best new rei...    9.2      1
# 13  Best new reissue A revolutionary classic of so...    9.2      1
# 14  Best new music The challenging art-poppers led...    9.2      1
# 15  Best new reissue Best new reissue 1 / 2 Albums...    9.2      1
# 16  Best new reissue Best new reissue 1 / 2 Albums...    9.1      1
# 17  Best new music Girls have been the subject of ...    9.1      1
# 18  Best new reissue Reissue of 1997 album serves ...    9.0      1
# 19  Best new music In a shocking turn, the Flaming...    9.0      1
# 20  Best new music One of the year's most anticipa...    9.0      1
# 21  Best new reissue This collection of tracks fro...    9.0      1
# 22  Best new music The second full-length from thi...    9.0      1
# 23  Best new reissue To mark Elvis' 75th birthday,...    9.0      1
#
#         Month Day  Year
# 0   September  11  2009
# 1    February  13  2009
# 2       March  26  2009
# 3        July   2  2009
# 4      August  25  2009
# 5     January   5  2009
# 6      August  26  2009
# 7    December   1  2009
# 8        July  30  2009
# 9   September  18  2009
# 10   November  24  2009
# 11   November   2  2009
# 12   November   6  2009
# 13       June  29  2009
# 14       June   9  2009
# 15      April  20  2009
# 16  September  14  2009
# 17  September  25  2009
# 18        May  15  2009
# 19    October  12  2009
# 20        May  26  2009
# 21   December   7  2009
# 22    October  23  2009
# 23   December   8  2009

# %% [markdown]
# We can identify that 24 albums had a score above 9.0 in 2009. Among my favorites are *Veckatimest* by Grizzly Bear, *Embryonic* by Flaming Lips, *Bitte Orca* by Dirty Projectors and *Merriweather Post Pavilion* by Animal Collective. Out of these, 15 albums were categorized as Rock music, making it the dominant genre in 2009.

# %% [markdown]
# ## Question 3: What is the overall best reviewed artist in Pitchfork history?
#
# In order to figure this out, we will have to group by artist and then find the mean score of each. The top 20 artists will then be compared in a bar graph and a boxplot.

# %%
artists_by_score = df.groupby('artist')[['score']].mean()
artists_by_score = artists_by_score.sort_values('score', ascending = False)
artists_by_score.head(20)
# Out:
#                                    score
# artist
# Slint                             10.000
# Glenn Gould                       10.000
# Stevie Wonder                     10.000
# Television / Adventure            10.000
# The Stone Roses                   10.000
# Talk Talk / Mark Hollis           10.000
# X-Ray Spex                        10.000
# Elvis Costello & The Attractions   9.750
# Ultramagnetic MC's                 9.700
# N.W.A.                             9.700
# D�Angelo                           9.600
# My Bloody Valentine                9.550
# Minutemen                          9.500
# Farben                             9.500
# John Coltrane                      9.500
# Lauryn Hill                        9.500
# A Tribe Called Quest               9.500
# Roxy Music                         9.500
# Morton Feldman / Ives Ensemble     9.500
# Prince / The Revolution            9.475

# %% [markdown]
# There are actually 7 artists with an average perfect score in Pitchfork reviews. These are:
# * Television / Adventure
# * Talk Talk / Mark Hollis
# * Stevie Wonder
# * X-Ray Spex
# * Glenn Gould
# * Slint
# * The Stone Roses
